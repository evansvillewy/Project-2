# %%
# Dependencies
import pandas as pd
file_one = "./Resources/US_Accidents_Dec19.csv"
file_one_df = pd.read_csv(file_one)

# %%
file_one_df.head()
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0  39.865147 -84.058723      NaN      NaN  ...       False   False  False
# 1  39.928059 -82.831184      NaN      NaN  ...       False   False  False
# 2  39.063148 -84.032608      NaN      NaN  ...       False   False  False
# 3  39.747753 -84.205582      NaN      NaN  ...       False   False  False
# 4  39.627781 -84.188354      NaN      NaN  ...       False   False  False
#
# ...

# %%
file_one_df.count()
# Out:
# ID                       2974335
# Source                   2974335
# TMC                      2246264
# Severity                 2974335
# Start_Time               2974335
# End_Time                 2974335
# Start_Lat                2974335
# Start_Lng                2974335
# End_Lat                   728071
# End_Lng                   728071
# Distance(mi)             2974335
# Description              2974334
# Number                   1056730
# Street                   2974335
# Side                     2974335
# City                     2974252
# County                   2974335
# State                    2974335
# Zipcode                  2973455
# Country                  2974335
# Timezone                 2971172
# Airport_Code             2968644
# Weather_Timestamp        2937630
# Temperature(F)           2918272
# Wind_Chill(F)            1121712
# Humidity(%)              2915162
# Pressure(in)             2926193
# Visibility(mi)           2908644
# ...

# %%
file_one_df.dtypes
# Out:
# ID                        object
# Source                    object
# TMC                      float64
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# End_Lat                  float64
# End_Lng                  float64
# Distance(mi)             float64
# Description               object
# Number                   float64
# Street                    object
# Side                      object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# ...

# %%
#get just the data we want four our analysis
traffic_df = (file_one_df[['ID','Source','Severity','Start_Time','Street','Side','City','County','State',
                           'Zipcode','Timezone','Temperature(F)','Wind_Chill(F)','Humidity(%)',
                           'Visibility(mi)','Wind_Speed(mph)','Weather_Condition','Sunrise_Sunset']])

# %%
# fix column names
traffic_df=traffic_df.rename(
    columns={'ID':'id','Source':'source','Severity':'severity','Start_Time':'start_time','Street':'street',
             'Side':'side','City':'city','County':'county','State':'state',
             'Zipcode':'zipcode','Timezone':'timezone','Temperature(F)':'temperature',
             'Wind_Chill(F)':'wind_chill','Humidity(%)':'humidity',
             'Visibility(mi)':'visibility','Wind_Speed(mph)':'wind_speed','Weather_Condition':'weather_condition',
             'Sunrise_Sunset':'sunrise_sunset'})

# %%
# fix column names
traffic_df
# Out:
#                 id    source  severity           start_time  \
# 0              A-1  MapQuest         3  2016-02-08 05:46:00
# 1              A-2  MapQuest         2  2016-02-08 06:07:59
# 2              A-3  MapQuest         2  2016-02-08 06:49:27
# 3              A-4  MapQuest         3  2016-02-08 07:23:34
# 4              A-5  MapQuest         2  2016-02-08 07:39:07
# ...            ...       ...       ...                  ...
# 2974330  A-2974354      Bing         2  2019-08-23 18:03:25
# 2974331  A-2974355      Bing         2  2019-08-23 19:11:30
# 2974332  A-2974356      Bing         2  2019-08-23 19:00:21
# 2974333  A-2974357      Bing         2  2019-08-23 19:00:21
# 2974334  A-2974358      Bing         2  2019-08-23 18:52:06
#
#                             street side          city          county state  \
# 0                           I-70 E    R        Dayton      Montgomery    OH
# 1                         Brice Rd    L  Reynoldsburg        Franklin    OH
# ...

# %%
from sqlalchemy import create_engine

def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = create_engine(database, echo=False)
        return conn
    except:
        print('Error creating db connection')
 
    return conn

# %%
database = 'sqlite:///./Resources/traffic.db'
conn = create_connection(database)

# %%
#delete data from table before reload
conn.execute('''delete from accidents''')

# %%
#load the accident data
traffic_df.to_sql(name="accidents", con=conn,
                  if_exists="append", index=False)

# %%
results = pd.read_sql_query(f'''SELECT *
                                    FROM accidents ;''', conn)

# %%
results["year"] = results["start_time"].map(lambda x: x[0:4])

# %%
results.head()
# Out:
#     id    source  severity           start_time                     street  \
# 0  A-1  MapQuest         3  2016-02-08 05:46:00                     I-70 E
# 1  A-2  MapQuest         2  2016-02-08 06:07:59                   Brice Rd
# 2  A-3  MapQuest         2  2016-02-08 06:49:27             State Route 32
# 3  A-4  MapQuest         3  2016-02-08 07:23:34                     I-75 S
# 4  A-5  MapQuest         2  2016-02-08 07:39:07  Miamisburg Centerville Rd
#
#   side          city      county state     zipcode    timezone  temperature  \
# 0    R        Dayton  Montgomery    OH       45424  US/Eastern         36.9
# 1    L  Reynoldsburg    Franklin    OH  43068-3402  US/Eastern         37.9
# 2    R  Williamsburg    Clermont    OH       45176  US/Eastern         36.0
# 3    R        Dayton  Montgomery    OH       45417  US/Eastern         35.1
# 4    R        Dayton  Montgomery    OH       45459  US/Eastern         36.0
#
# ...

# %%
year_group = results.groupby(['year'])

# %%
year_df = year_group.count()

# %%
year_df.head()
# Out:
#           id  source  severity  start_time  street    side    city  county  \
# year
# 2015       1       1         1           1       1       1       1       1
# 2016  410600  410600    410600      410600  410600  410600  410573  410600
# 2017  717483  717483    717483      717483  717483  717483  717456  717483
# 2018  892615  892615    892615      892615  892615  892615  892605  892615
# 2019  953630  953630    953630      953630  953630  953630  953611  953630
#
#        state  zipcode  timezone  temperature  wind_chill  humidity  \
# year
# 2015       1        1         1            0           0         0
# 2016  410600   410484    410471       404137       41172    403577
# 2017  717483   717308    716978       703101      108682    702496
# 2018  892615   892368    891537       874588      167462    873725
# 2019  953630   953288    952179       936446      804396    935364
#
#       visibility  wind_speed  weather_condition  sunrise_sunset
# year
# ...

# %%
df_2019 = results[(results['year'] =="2019")]

# %%
df_2019.count()
# Out:
# id                   953630
# source               953630
# severity             953630
# start_time           953630
# street               953630
# side                 953630
# city                 953611
# county               953630
# state                953630
# zipcode              953288
# timezone             952179
# temperature          936446
# wind_chill           804396
# humidity             935364
# visibility           935149
# wind_speed           893547
# weather_condition    935347
# sunrise_sunset       953608
# year                 953630
# dtype: int64

# %%
#get just the data we want four our analysis
df_2019 = (df_2019[['id','source','severity','start_time','street',
             'side','city','county','state',
             'zipcode','timezone','temperature',
             'wind_chill','humidity',
             'visibility','wind_speed','weather_condition',
             'sunrise_sunset']])

# %%
#delete data from table before reload
conn.execute('''delete from accidents''')

# %%
#load the accident data
df_2019.to_sql(name="accidents", con=conn,
                  if_exists="append", index=False)

# %%
#Export the starbucks city data to csv
output_data_file = "Resources/US_Accidents_2019.csv"
df_2019.to_csv(output_data_file, index = None, header=True)
